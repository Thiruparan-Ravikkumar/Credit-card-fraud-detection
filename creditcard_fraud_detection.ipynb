# %% [markdown]
# Anomaly Detection in credit card transaction data to predict fraud transactions.
# Autoencoder Neural Network (implemented in Keras) is modelled for fraud detection in credit card transactions.
# The trained model will be evaluated on pre-labeled to test the accuracy of the model.
#
# An autoencoder is an unsupervised learning technique for neural networks that learns efficient data representations (encoding) by training the network to ignore signal “noise.”
#
# The autoencoder network has three layers, the input, a hidden layer for encoding, and the output decoding layer. Using backpropagation, the unsupervised algorithm continuously trains itself by setting the target output values to equal the inputs. This forces the smaller hidden encoding layer to use dimensional reduction to eliminate noise and reconstruct the inputs.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42

# %%
df = pd.read_csv("creditcard.csv")

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# The data contains 284,807 European credit card transactions that occurred over two days with 492 fraudulent transactions.
# Everything except the time and amount has been reduced by a Principle Component Analysis (PCA) for privacy concerns

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %%
LABELS = ["Normal", "Fraud"]
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]

# %%
frauds.shape
# Out:
# (492, 31)

# %%
normal.shape
# Out:
# (284315, 31)

# %%
frauds.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount VS Transaction class')
bins = 50
ax1.hist(frauds.Amount,bins=bins)
ax1.set_title('Fraud')
plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')


ax2.hist(normal.Amount,bins=bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %%
bins = np.linspace(200, 2500, 100)
plt.figure(figsize=(14, 8))
plt.hist(normal.Amount, bins, alpha=1, density=True, label='Normal')
plt.hist(frauds.Amount, bins, alpha=0.6, density=True, label='Fraud')
plt.legend(loc='upper right')
plt.title("Amount by percentage of transactions (transactions \$200+)")
plt.xlabel("Transaction amount (USD)")
plt.ylabel("Percentage of transactions (%)");
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

data = df.drop(['Time'], axis=1)

data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

# %%
X_train.shape
# Out:
# (227451, 29)

# %%
input_dim = X_train.shape[1]
encoding_dim = 14

# %%
input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim, activation="tanh", 
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)

decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
nb_epoch = 100
batch_size = 32

autoencoder.compile(optimizer='adam', 
                    loss='mean_squared_error', 
                    metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='.\logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Train on 227451 samples, validate on 56962 samples
# Epoch 1/100
# 227451/227451 [==============================] - 18s 80us/step - loss: 0.8211 - accuracy: 0.5722 - val_loss: 0.8026 - val_accuracy: 0.6170
# Epoch 2/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7504 - accuracy: 0.6323 - val_loss: 0.7701 - val_accuracy: 0.6436
# Epoch 3/100
# 227451/227451 [==============================] - 20s 89us/step - loss: 0.7343 - accuracy: 0.6441 - val_loss: 0.7650 - val_accuracy: 0.6445
# Epoch 4/100
# 227451/227451 [==============================] - 17s 77us/step - loss: 0.7292 - accuracy: 0.6506 - val_loss: 0.7640 - val_accuracy: 0.6467
# Epoch 5/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7266 - accuracy: 0.6532 - val_loss: 0.7584 - val_accuracy: 0.6547
# Epoch 6/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7241 - accuracy: 0.6551 - val_loss: 0.7569 - val_accuracy: 0.6573
# Epoch 7/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7221 - accuracy: 0.6579 - val_loss: 0.7544 - val_accuracy: 0.6619
# Epoch 8/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7205 - accuracy: 0.6599 - val_loss: 0.7519 - val_accuracy: 0.6663
# Epoch 9/100
# 227451/227451 [==============================] - 19s 83us/step - loss: 0.7192 - accuracy: 0.6629 - val_loss: 0.7495 - val_accuracy: 0.6664
# Epoch 10/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7175 - accuracy: 0.6659 - val_loss: 0.7491 - val_accuracy: 0.6678
# Epoch 11/100
# 227451/227451 [==============================] - 18s 81us/step - loss: 0.7169 - accuracy: 0.6671 - val_loss: 0.7488 - val_accuracy: 0.6700
# Epoch 12/100
# 227451/227451 [==============================] - 19s 86us/step - loss: 0.7162 - accuracy: 0.6684 - val_loss: 0.7475 - val_accuracy: 0.6708
# Epoch 13/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7159 - accuracy: 0.6678 - val_loss: 0.7478 - val_accuracy: 0.6712
# Epoch 14/100
# 227451/227451 [==============================] - 17s 77us/step - loss: 0.7156 - accuracy: 0.6687 - val_loss: 0.7503 - val_accuracy: 0.6687
# Epoch 15/100
# 227451/227451 [==============================] - 19s 82us/step - loss: 0.7152 - accuracy: 0.6686 - val_loss: 0.7526 - val_accuracy: 0.6655
# Epoch 16/100
# 227451/227451 [==============================] - 19s 85us/step - loss: 0.7148 - accuracy: 0.6689 - val_loss: 0.7476 - val_accuracy: 0.6705
# Epoch 17/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7145 - accuracy: 0.6684 - val_loss: 0.7474 - val_accuracy: 0.6711
# Epoch 18/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7144 - accuracy: 0.6692 - val_loss: 0.7475 - val_accuracy: 0.6691
# Epoch 19/100
# 227451/227451 [==============================] - 23s 100us/step - loss: 0.7144 - accuracy: 0.6698 - val_loss: 0.7465 - val_accuracy: 0.6723
# Epoch 20/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7140 - accuracy: 0.6703 - val_loss: 0.7464 - val_accuracy: 0.6695
# Epoch 21/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7138 - accuracy: 0.6699 - val_loss: 0.7489 - val_accuracy: 0.6700
# Epoch 22/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7137 - accuracy: 0.6702 - val_loss: 0.7478 - val_accuracy: 0.6669
# Epoch 23/100
# 227451/227451 [==============================] - 18s 81us/step - loss: 0.7136 - accuracy: 0.6710 - val_loss: 0.7508 - val_accuracy: 0.6722
# Epoch 24/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7137 - accuracy: 0.6710 - val_loss: 0.7468 - val_accuracy: 0.6688
# Epoch 25/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7133 - accuracy: 0.6710 - val_loss: 0.7509 - val_accuracy: 0.6663
# Epoch 26/100
# 227451/227451 [==============================] - 15s 68us/step - loss: 0.7135 - accuracy: 0.6701 - val_loss: 0.7466 - val_accuracy: 0.6727
# Epoch 27/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7131 - accuracy: 0.6703 - val_loss: 0.7481 - val_accuracy: 0.6688
# Epoch 28/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7133 - accuracy: 0.6708 - val_loss: 0.7457 - val_accuracy: 0.6726
# Epoch 29/100
# 227451/227451 [==============================] - 17s 77us/step - loss: 0.7127 - accuracy: 0.6705 - val_loss: 0.7450 - val_accuracy: 0.6743
# Epoch 30/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7129 - accuracy: 0.6709 - val_loss: 0.7477 - val_accuracy: 0.6677
# Epoch 31/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7120 - accuracy: 0.6707 - val_loss: 0.7475 - val_accuracy: 0.6677
# Epoch 32/100
# 227451/227451 [==============================] - 19s 83us/step - loss: 0.7119 - accuracy: 0.6711 - val_loss: 0.7449 - val_accuracy: 0.6656
# Epoch 33/100
# 227451/227451 [==============================] - 17s 77us/step - loss: 0.7116 - accuracy: 0.6701 - val_loss: 0.7489 - val_accuracy: 0.6652
# Epoch 34/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7113 - accuracy: 0.6707 - val_loss: 0.7449 - val_accuracy: 0.6695
# Epoch 35/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7116 - accuracy: 0.6702 - val_loss: 0.7487 - val_accuracy: 0.6690
# Epoch 36/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7114 - accuracy: 0.6701 - val_loss: 0.7441 - val_accuracy: 0.6727
# Epoch 37/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7113 - accuracy: 0.6702 - val_loss: 0.7437 - val_accuracy: 0.6708
# Epoch 38/100
# 227451/227451 [==============================] - 17s 77us/step - loss: 0.7109 - accuracy: 0.6711 - val_loss: 0.7445 - val_accuracy: 0.6668
# Epoch 39/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7110 - accuracy: 0.6708 - val_loss: 0.7449 - val_accuracy: 0.6695
# Epoch 40/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7109 - accuracy: 0.6706 - val_loss: 0.7452 - val_accuracy: 0.6691
# Epoch 41/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7108 - accuracy: 0.6708 - val_loss: 0.7433 - val_accuracy: 0.6722
# Epoch 42/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7103 - accuracy: 0.6704 - val_loss: 0.7455 - val_accuracy: 0.6738
# Epoch 43/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7105 - accuracy: 0.6706 - val_loss: 0.7432 - val_accuracy: 0.6702
# Epoch 44/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7104 - accuracy: 0.6715 - val_loss: 0.7429 - val_accuracy: 0.6812
# Epoch 45/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7103 - accuracy: 0.6717 - val_loss: 0.7442 - val_accuracy: 0.6658
# Epoch 46/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7103 - accuracy: 0.6711 - val_loss: 0.7450 - val_accuracy: 0.6718
# Epoch 47/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7104 - accuracy: 0.6716 - val_loss: 0.7433 - val_accuracy: 0.6721
# Epoch 48/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7103 - accuracy: 0.6710 - val_loss: 0.7438 - val_accuracy: 0.6753
# Epoch 49/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7102 - accuracy: 0.6712 - val_loss: 0.7479 - val_accuracy: 0.6685
# Epoch 50/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7099 - accuracy: 0.6709 - val_loss: 0.7442 - val_accuracy: 0.6684
# Epoch 51/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7098 - accuracy: 0.6716 - val_loss: 0.7572 - val_accuracy: 0.6693
# Epoch 52/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7103 - accuracy: 0.6711 - val_loss: 0.7446 - val_accuracy: 0.6707
# Epoch 53/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7099 - accuracy: 0.6714 - val_loss: 0.7448 - val_accuracy: 0.6727
# Epoch 54/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7100 - accuracy: 0.6722 - val_loss: 0.7428 - val_accuracy: 0.6734
# Epoch 55/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7103 - accuracy: 0.6712 - val_loss: 0.7445 - val_accuracy: 0.6715
# Epoch 56/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7103 - accuracy: 0.6717 - val_loss: 0.7456 - val_accuracy: 0.6674
# Epoch 57/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7094 - accuracy: 0.6715 - val_loss: 0.7457 - val_accuracy: 0.6692
# Epoch 58/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7099 - accuracy: 0.6712 - val_loss: 0.7426 - val_accuracy: 0.6758
# Epoch 59/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7098 - accuracy: 0.6719 - val_loss: 0.7433 - val_accuracy: 0.6706
# Epoch 60/100
# 227451/227451 [==============================] - 14s 63us/step - loss: 0.7096 - accuracy: 0.6717 - val_loss: 0.7455 - val_accuracy: 0.6671
# Epoch 61/100
# 227451/227451 [==============================] - 15s 66us/step - loss: 0.7101 - accuracy: 0.6714 - val_loss: 0.7437 - val_accuracy: 0.6717
# Epoch 62/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7098 - accuracy: 0.6711 - val_loss: 0.7426 - val_accuracy: 0.6717
# Epoch 63/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7098 - accuracy: 0.6713 - val_loss: 0.7456 - val_accuracy: 0.6658
# Epoch 64/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7096 - accuracy: 0.6715 - val_loss: 0.7425 - val_accuracy: 0.6704
# Epoch 65/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7097 - accuracy: 0.6712 - val_loss: 0.7434 - val_accuracy: 0.6740
# Epoch 66/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7096 - accuracy: 0.6721 - val_loss: 0.7434 - val_accuracy: 0.6682
# Epoch 67/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7095 - accuracy: 0.6718 - val_loss: 0.7426 - val_accuracy: 0.6722
# Epoch 68/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7097 - accuracy: 0.6717 - val_loss: 0.7423 - val_accuracy: 0.6746
# Epoch 69/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7095 - accuracy: 0.6718 - val_loss: 0.7428 - val_accuracy: 0.6752
# Epoch 70/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7091 - accuracy: 0.6719 - val_loss: 0.7446 - val_accuracy: 0.6716
# Epoch 71/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7093 - accuracy: 0.6713 - val_loss: 0.7430 - val_accuracy: 0.6655
# Epoch 72/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7095 - accuracy: 0.6723 - val_loss: 0.7426 - val_accuracy: 0.6655
# Epoch 73/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7091 - accuracy: 0.6715 - val_loss: 0.7434 - val_accuracy: 0.6774
# Epoch 74/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7095 - accuracy: 0.6715 - val_loss: 0.7411 - val_accuracy: 0.6708
# Epoch 75/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7095 - accuracy: 0.6720 - val_loss: 0.7426 - val_accuracy: 0.6798
# Epoch 76/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7091 - accuracy: 0.6723 - val_loss: 0.7441 - val_accuracy: 0.6723
# Epoch 77/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7092 - accuracy: 0.6718 - val_loss: 0.7607 - val_accuracy: 0.6604
# Epoch 78/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7088 - accuracy: 0.6718 - val_loss: 0.7417 - val_accuracy: 0.6635
# Epoch 79/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7089 - accuracy: 0.6718 - val_loss: 0.7418 - val_accuracy: 0.6727
# Epoch 80/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7096 - accuracy: 0.6717 - val_loss: 0.7436 - val_accuracy: 0.6768
# Epoch 81/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7091 - accuracy: 0.6727 - val_loss: 0.7430 - val_accuracy: 0.6697
# Epoch 82/100
# 227451/227451 [==============================] - 17s 77us/step - loss: 0.7088 - accuracy: 0.6723 - val_loss: 0.7474 - val_accuracy: 0.6620
# Epoch 83/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7090 - accuracy: 0.6721 - val_loss: 0.7402 - val_accuracy: 0.6782
# Epoch 84/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7088 - accuracy: 0.6727 - val_loss: 0.7451 - val_accuracy: 0.6668
# Epoch 85/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7087 - accuracy: 0.6724 - val_loss: 0.7450 - val_accuracy: 0.6712
# Epoch 86/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7087 - accuracy: 0.6724 - val_loss: 0.7419 - val_accuracy: 0.6754
# Epoch 87/100
# 227451/227451 [==============================] - 17s 77us/step - loss: 0.7091 - accuracy: 0.6727 - val_loss: 0.7411 - val_accuracy: 0.6765
# Epoch 88/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7084 - accuracy: 0.6719 - val_loss: 0.7426 - val_accuracy: 0.6746
# Epoch 89/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7087 - accuracy: 0.6726 - val_loss: 0.7419 - val_accuracy: 0.6716
# Epoch 90/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7089 - accuracy: 0.6721 - val_loss: 0.7450 - val_accuracy: 0.6707
# Epoch 91/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7086 - accuracy: 0.6724 - val_loss: 0.7434 - val_accuracy: 0.6644
# Epoch 92/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7089 - accuracy: 0.6725 - val_loss: 0.7430 - val_accuracy: 0.6730
# Epoch 93/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7094 - accuracy: 0.6713 - val_loss: 0.7419 - val_accuracy: 0.6730
# Epoch 94/100
# 227451/227451 [==============================] - 15s 68us/step - loss: 0.7088 - accuracy: 0.6722 - val_loss: 0.7427 - val_accuracy: 0.6708
# Epoch 95/100
# 227451/227451 [==============================] - 14s 62us/step - loss: 0.7086 - accuracy: 0.6729 - val_loss: 0.7440 - val_accuracy: 0.6690
# Epoch 96/100
# 227451/227451 [==============================] - 16s 68us/step - loss: 0.7086 - accuracy: 0.6723 - val_loss: 0.7457 - val_accuracy: 0.6714
# Epoch 97/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7085 - accuracy: 0.6730 - val_loss: 0.7446 - val_accuracy: 0.6730
# Epoch 98/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7086 - accuracy: 0.6718 - val_loss: 0.7420 - val_accuracy: 0.6741
# Epoch 99/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7088 - accuracy: 0.6724 - val_loss: 0.7415 - val_accuracy: 0.6774
# Epoch 100/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7085 - accuracy: 0.6720 - val_loss: 0.7439 - val_accuracy: 0.6673

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(X_test)

# %%
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.736520      0.001720
# std                3.432234      0.041443
# min                0.058017      0.000000
# 25%                0.249528      0.000000
# 50%                0.399186      0.000000
# 75%                0.631776      0.000000
# max              266.839609      1.000000

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %%
threshold = 3.7

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
